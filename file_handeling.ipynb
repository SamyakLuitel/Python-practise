# %%
pwd
# Out:
# '/home/samyak'

# %%
import os 
print(os.getcwd())
# Out:
# /home/samyak

# %%
f = open("filehandling.txt")

# %%
j=f.read()

# %%
print(j)
# Out:
# mode ="r" is read only
# mode ="w" is write only (eill overwrite files or create new !)
# mode = "a" is append only(will add on to files)
# mode = "r+" is reading and writing
# mode ="w+ " is writing and reading (Overwirts existing files or creates a new file!)

# %%
k=f.readlines()

# %%
f.seek(0,0)
# Out:
# 0

# %%
print(k)
# Out:
# ['mode ="w" is write only (eill overwrite files or create new !)\n', 'mode = "a" is append only(will add on to files)\n', 'mode = "r+" is reading and writing \n', 'mode ="w+ " is writing and reading (Overwirts existing files or creates a new file!)\n']

# %%
fin = open("word.txt","w+")

# %%
print(fin)
# Out:
# <_io.TextIOWrapper name='word.txt' mode='w' encoding='UTF-8'>

# %%
fin.readline()
# Out:
# ''

# %%
print(j)
# Out:
# mode ="r" is read only
# mode ="w" is write only (eill overwrite files or create new !)
# mode = "a" is append only(will add on to files)
# mode = "r+" is reading and writing
# mode ="w+ " is writing and reading (Overwirts existing files or creates a new file!)

# %%
f.seek(0,0)
line = f.readline()
word = line.strip()
print(line)
# Out:
# mode ="r" is read only

# %%
print(word)
# Out:
# mode ="r" is read only

# %%
fout =open("output.txt","w")
line1 = "this is the first line "
fout.write(line1)
# Out:
# 23

# %%
fout.close()

# %%
fout=open("output.txt","r")

# %%
re=fout.read()

# %%
print(re)
# Out:
# this is the first line

# %%
fout=open("output.txt","a")

# %%
fout.write("this is another line that i have added using append ")
# Out:
# 52

# %%
fout.close()

# %% [markdown]
# <h3>hello</h3>

# %%
fout = open("output.txt","r+")

# %%
g= fout.read()

# %%
print(g)
# Out:
# this is the first line this is another line that i have added using append

# %%
re = fout.readlines()

# %%
print(re)
# Out:
# ['this is the first line this is another line that i have added using append ']

# %%
fout.seek(0,0)
# Out:
# 0

# %%
fout.close()

# %%
camels = 900913

# %%
"%d" % camels
# Out:
# '900913'

# %%
google = 900913
"this %d is number for google" %google
# Out:
# 'this 900913 is number for google'

# %%
"the number equivalent for google is %d" %google
# Out:
# 'the number equivalent for google is 900913'

# %%
"in %d years i have spotted %g %s ."%(3,0.1,"cammels")
# Out:
# 'in 3 years i have spotted 0.1 cammels .'

# %%
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /home/samyak

# %%
print("cwd stsnds for current working directory")
# Out:
# cwd stsnds for current working directory

# %%
os.path.abspath("output.txt")
# Out:
# '/home/samyak/output.txt'

# %%
os.path.isdir("words.txt")
# Out:
# False

# %%
os.path.isdir("home")
# Out:
# False

# %%
os.path.isdir("Documents")
# Out:
# True

# %%
import os
cwd = os.getcwd()
os.listdir(cwd)
# Out:
# ['snap',
#  '.python_history-07469.tmp',
#  "PlayOnLinux's virtual drives",
#  'newfile.txt',
#  'Untitled7.ipynb',
#  'Untitled4.ipynb',
#  'Untitled6.ipynb',
#  '.PlayOnLinux',
#  '.python_history-08423.tmp',
#  '.pki',
#  '.redeclipse',
#  '.thunderbird',
#  'Untitled9.ipynb',
#  'Untitled.ipynb',
#  'f.txt',
#  'filehandaling.txt',
#  '.local',
#  '.thumbnails',
#  '.octave_hist',
#  'Pictures',
#  'word.txt',
#  'Untitled8.ipynb',
#  '.python_history-05909.tmp',
#  'Videos',
#  '.conda',
#  'Downloads',
#  '.gimp-2.8',
#  '.profile',
#  '.python_history-06085.tmp',
#  'Templates',
#  '.gnupg',
#  '.pylint.d',
#  'output.txt',
#  '.vscode',
#  'Public',
#  'Calibre Library',
#  '.condarc',
#  'Untitled1.ipynb',
#  '.atom',
#  '.sudo_as_admin_successful',
#  'myfile.txt',
#  '.pam_environment',
#  'Untitled5.ipynb',
#  '.mozilla',
#  '.anaconda',
#  '.gitconfig',
#  '.config',
#  '.ipynb_checkpoints',
#  'Documents',
#  '.ICEauthority',
#  '.bash_logout',
#  'Untitled10.ipynb',
# ...

# %%
import os
def walk(dir):
    for name in os.listdir(dir):
        path=os.path.join(dir, name)
        if os.path.isfile(path):
            print(path)
        else:
            walk(path)
cwd=os.getcwd()
walk(cwd)
# Out:
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-down-insens.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-down-prelight.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-down-small-insens.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-down-small-prelight.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-down-small.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-down.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-left-insens.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-left-prelight.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-left.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-right-insens.png
# /home/samyak/snap/spotify/36/.themes/Adwaita/gtk-2.0/Arrows/arrow-right-prelight.png
# ...

# %%
try:
    fin =open("bad_file")
    for line in fin:
        print (line) 
    fin.close()
except:
    print("somethisg went wrong")
# Out:
# somethisg went wrong

# %%
import os 
import shutil
